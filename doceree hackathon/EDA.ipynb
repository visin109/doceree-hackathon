# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("hcp_train.csv", encoding="latin-1")
df
test=pd.read_csv("hcp_test.csv",encoding="latin-1")
test
# Out:
#            ID DEVICETYPE  PLATFORM_ID     BIDREQUESTIP  \
# 0      115501    Desktop            2   75.189.231.103
# 1      115502     Mobile            2    24.101.33.158
# 2      115503    Desktop            2  172.118.216.142
# 3      115504    Desktop            7   71.105.120.171
# 4      115505    Desktop            2     73.82.211.73
# ...       ...        ...          ...              ...
# 28488  143989    Desktop            2   69.202.233.241
# 28489  143990    Desktop            7      75.4.190.65
# 28490  143991    Desktop            7    137.52.180.45
# 28491  143992    Desktop            8      66.249.66.4
# 28492  143993    Desktop            2   107.194.33.149
#
#                             USERPLATFORMUID         USERCITY  USERZIPCODE  \
# 0      0d5041ff-f0b6-4d1a-9ad7-0a29f7d485b4     Fayetteville      28305.0
# 1      c8396dd0-969f-4d99-a40b-b7bb1f516154    Conneaut Lake      16316.0
# 2      3c97a081-6518-43f8-9f26-369759cfb471           Covina      91724.0
# ...

# %%
df.head()
# Out:
#      ID DEVICETYPE  PLATFORM_ID    BIDREQUESTIP  \
# 0  1001    Desktop            2    170.173.0.22
# 1  1002    Desktop            2   65.216.253.25
# 2  1003    Desktop            2    66.232.79.22
# 3  1004    Desktop            3  137.54.125.246
# 4  1005     Mobile            7  174.202.231.99
#
#                         USERPLATFORMUID     USERCITY  USERZIPCODE  \
# 0  6974dcaa-f932-480e-9fb5-c52e20e1393a     Portland      97206.0
# 1  c12f3f8f-8fcf-484a-90e1-1ac04db8cdcf    Arlington      22202.0
# 2  a698de4b-e200-46dd-b5fb-40402175ae18  New Meadows      83654.0
# 3  45967533-75c8-4fbd-a00c-e6ff20447aaa          NaN  229114624.0
# 4  a17e25be-532d-4cf5-b916-9308c8c3961f      Houston      77008.0
#
#                                            USERAGENT            PLATFORMTYPE  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  Online Medical Journal
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  Online Medical Journal
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of             ID DEVICETYPE  PLATFORM_ID    BIDREQUESTIP  \
# 0         1001    Desktop            2    170.173.0.22
# 1         1002    Desktop            2   65.216.253.25
# 2         1003    Desktop            2    66.232.79.22
# 3         1004    Desktop            3  137.54.125.246
# 4         1005     Mobile            7  174.202.231.99
# ...        ...        ...          ...             ...
# 113932  114933    Desktop            2    68.82.97.126
# 113933  114934    Desktop            2  104.172.11.109
# 113934  114935    Desktop            7   174.21.94.113
# 113935  114936     Mobile            2  69.253.129.131
# 113936  114937     Mobile            2  108.41.233.175
#
#                              USERPLATFORMUID      USERCITY  USERZIPCODE  \
# 0       6974dcaa-f932-480e-9fb5-c52e20e1393a      Portland      97206.0
# 1       c12f3f8f-8fcf-484a-90e1-1ac04db8cdcf     Arlington      22202.0
# ...

# %%
df.dtypes
# Out:
# ID                   int64
# DEVICETYPE          object
# PLATFORM_ID          int64
# BIDREQUESTIP        object
# USERPLATFORMUID     object
# USERCITY            object
# USERZIPCODE        float64
# USERAGENT           object
# PLATFORMTYPE        object
# CHANNELTYPE         object
# URL                 object
# KEYWORDS            object
# TAXONOMY            object
# IS_HCP             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ID               113937 non-null  int64
#  1   DEVICETYPE       113937 non-null  object
#  2   PLATFORM_ID      113937 non-null  int64
#  3   BIDREQUESTIP     113937 non-null  object
#  4   USERPLATFORMUID  113933 non-null  object
#  5   USERCITY         107578 non-null  object
#  6   USERZIPCODE      109345 non-null  float64
#  7   USERAGENT        113935 non-null  object
#  8   PLATFORMTYPE     113937 non-null  object
#  9   CHANNELTYPE      113937 non-null  object
#  10  URL              113937 non-null  object
#  11  KEYWORDS         113937 non-null  object
#  12  TAXONOMY         32313 non-null   object
#  13  IS_HCP           113936 non-null  float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 12.2+ MB

# %%
df.describe()
# Out:
#                   ID    PLATFORM_ID   USERZIPCODE         IS_HCP
# count  113937.000000  113937.000000  1.093450e+05  113936.000000
# mean    57969.000000       3.574993  1.830240e+07       0.299993
# std     32890.923148       2.569019  1.066908e+08       0.458257
# min      1001.000000       1.000000  6.020000e+02       0.000000
# 25%     29485.000000       2.000000  1.935500e+04       0.000000
# 50%     57969.000000       2.000000  4.321000e+04       0.000000
# 75%     86453.000000       6.000000  7.709000e+04       1.000000
# max    114937.000000      16.000000  9.970149e+08       1.000000

# %%
df.isnull().sum()
# Out:
# ID                     0
# DEVICETYPE             0
# PLATFORM_ID            0
# BIDREQUESTIP           0
# USERPLATFORMUID        4
# USERCITY            6359
# USERZIPCODE         4592
# USERAGENT              2
# PLATFORMTYPE           0
# CHANNELTYPE            0
# URL                    0
# KEYWORDS               0
# TAXONOMY           81624
# IS_HCP                 1
# dtype: int64

# %%
# Count unique values in categorical columns
print(df["DEVICETYPE"].value_counts())
print(df["PLATFORMTYPE"].value_counts())
print(df["CHANNELTYPE"].value_counts())
# Out:
# Desktop    78423
# Mobile     32065
# Tablet      3425
# Unknown       24
# Name: DEVICETYPE, dtype: int64
# Online Medical Journal      110120
# Online Learning Portal        2978
# Medical News Platform          798
# Electronic Health Record        40
# Tele-medicine Platform           1
# Name: PLATFORMTYPE, dtype: int64
# Website    113937
# Name: CHANNELTYPE, dtype: int64

# %%
#Distribution of traget variable(HCP)
sns.countplot(x="IS_HCP", data=df)
plt.xlabel("IS_HCP")
plt.ylabel("Count")
plt.title("Distribution of HCP")
plt.show()

# %% [markdown]
# Result:
# It provides insights into the proportion of HCP and non-HCP users. If the bars are approximately equal in height, it indicates a balanced distribution. But here we can clearly see one bar is much taller than the other, it signifies an imbalanced distribution. The distribution of Non-HCP is greater than HCP.

# %%
# Distribution of IS_HCP by Device Type
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='DEVICETYPE', hue='IS_HCP')
plt.xlabel('Device Type')
plt.ylabel('Count')
plt.title('Distribution of IS_HCP by Device Type')
plt.legend(title='IS_HCP')
plt.show()

# %% [markdown]
# Result:
# The countplot of the IS_HCP variable across different device types provides insights into the distribution of HCP and non-HCP users across devices and their device usage preferences. This information can be valuable for understanding the user behavior and optimizing the platform for better user experience.

# %%
# Distribution of IS_HCP by Platform Type and User ZIP Code
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='PLATFORMTYPE', y='USERZIPCODE', hue='IS_HCP')
plt.xlabel('Platform Type')
plt.ylabel('User ZIP Code')
plt.title('Distribution of IS_HCP by Platform Type and User ZIP Code')
plt.legend(title='IS_HCP')
plt.show()

# %% [markdown]
# Result:
# The bar plot of the IS_HCP variable across platform types and user ZIP codes provides insights into the distribution of HCP and non-HCP users across different locations and platform preferences. This visualization helps understand the relationship between HCP status, platform usage, and geographical distribution, which can be useful for targeted marketing, resource allocation, and platform optimization strategies.

# %%
# Categorical variables vs. target variable
for col in categorical_cols:
    sns.countplot(x=col, hue='IS_HCP', data=df)
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Result:
# the countplots for categorical variables provide insights into the relationship between the variables and the target variable, helping identify influential categories and understand the preferences and characteristics of HCPs within the dataset. These insights can guide feature selection, model building, and decision-making processes for solving the given classification problem

# %%
hcp_with_taxonomy = df[df['IS_HCP'] == 1].dropna(subset=['TAXONOMY'])
hcp_without_taxonomy = df[df['IS_HCP'] == 1].dropna(subset=['TAXONOMY'], how='all')
non_hcp_data = df[df['IS_HCP'] == 0]

# Plot the proportions of HCPs with and without taxonomy
hcp_taxonomy_counts = [len(hcp_with_taxonomy), len(hcp_without_taxonomy)]
labels = ['HCP with Taxonomy', 'HCP without Taxonomy']
plt.pie(hcp_taxonomy_counts, labels=labels, autopct='%1.1f%%')
plt.title('Proportion of HCPs with and without Taxonomy')
plt.show()

# %% [markdown]
# Result :
# This provides insights into the availability of taxonomy information among HCPs and the proportions of HCPs with and without taxonomy. This visualization helps understand the completeness of the taxonomy data and highlights the importance of accurately identifying the specialization or taxonomy of healthcare professionals in the given problem context.

# %%
# Plot the top 10 specializations (taxonomies)
top_specializations = df["TAXONOMY"].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_specializations.index, y=top_specializations.values)
plt.xlabel("Specialization (Taxonomy)")
plt.ylabel("Count")
plt.title("Top 10 Specializations")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Result :
# This provides insights into the distribution and prominence of the top 10 specializations (taxonomies) among healthcare professionals in the dataset. This information can help identify areas of specialization that are most prevalent and guide decision-making processes in various healthcare-related contexts.

# %%
# Distribution of the specialization taxonomy
sns.countplot(x="TAXONOMY", data=df)
plt.xlabel("TAXONOMY")
plt.ylabel("Count")
plt.title("Distribution of Specialization Taxonomy")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Result:
# The countplot of the specialization taxonomy provides insights into the distribution and frequency of different specializations among healthcare professionals in the dataset. This visualization helps in understanding the prevalence, diversity, and popularity of specializations, which can inform decision-making processes related to healthcare services, resource allocation, and identifying areas of expertise within the given problem context.

# %%
# Correlation matrix
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Result:
# The correlation matrix and heatmap provide insights into the strength and patterns of correlations among the numerical variables in the dataset. This information can guide feature selection, identify potential multicollinearity, and help understand the relationships between different features, ultimately aiding in building an accurate and interpretable model for the given problem.

# %%
# Visualize categorical features
categorical_features = ["DEVICETYPE", "PLATFORMTYPE", "CHANNELTYPE"]
for feature in categorical_features:
    sns.countplot(x=feature, data=df)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(f"Distribution of {feature}")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Result :
# The countplots of categorical features provide insights into the distribution and frequencies of categories within each feature. This information helps in understanding the prevalence, importance, and comparisons between categories, aiding in decision-making processes and addressing specific aspects of the problem at hand.

# %%
# Visualize numerical features
numerical_features = ["ID", "PLATFORM_ID"]
for feature in numerical_features:
    sns.histplot(df[feature], kde=True)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(f"Distribution of {feature}")
    plt.show()

# %% [markdown]
# Result:
# The histograms with KDE plots of numerical features provide insights into the distribution and patterns of numerical values within each feature. This information helps in understanding the central tendency, range, spread, and shape of the distributions, aiding in decision-making processes and addressing specific aspects of the problem at hand.

# %%
# Extract relevant information from USERAGENT, URL, and KEYWORDS
df['USERAGENT_info'] = df['USERAGENT'].str.extract(r'\(([^\)]+)\)')
df['URL_keywords'] = df['URL'].str.split('/').str[-1]
df['KEYWORDS'] = df['KEYWORDS'].str.lower()

# %% [markdown]
# Result:
# These transformations provide additional columns with relevant information that can be used for further analysis and feature engineering. They enable insights into the user's device and software details from the USERAGENT_info column, identification and grouping based on keywords in the URL_keywords column, and standardized processing of keywords in the KEYWORDS column. These insights can potentially contribute to building a more robust model for the given problem by incorporating these extracted features.

# %%
# Analyze the frequency of specific keywords or phrases
keyword_counts = df['KEYWORDS'].value_counts().head(10)

print("Top 10 Keyword Frequencies:")
for keyword, count in keyword_counts.items():
    print(f"{keyword}: {count}")
# Out:
# Top 10 Keyword Frequencies:
# family practice|drainage|clinical|dermatology|ophthalmology|medicine|allergic|general|diagnosis|neurology|hepatology|health|cardiovascular|surgical|psychiatry|oral|urology|cardiology|gastroenterology|orthopedics|erythema|arthritis|asthma|cellulitis|pediatrics|surgery|false|oncology|rheumatology: 5317
# ...

# %% [markdown]
# Result:
# Analyzing the frequency of specific keywords or phrases provides insights into the importance, relevance, and patterns associated with them in the dataset. These insights can be valuable for decision-making, feature engineering, or understanding user behavior within the context of the problem being addressed.

# %%
# HCP identified but taxonomy not populated
hcp_no_taxonomy = df[(df["IS_HCP"] == 1) & df["TAXONOMY"].isnull()]

# Both HCP and taxonomy identified
hcp_with_taxonomy = df[(df["IS_HCP"] == 1) & df["TAXONOMY"].notnull()]

# No information about HCP
no_hcp_info = df[df["IS_HCP"] == 0]

# %% [markdown]
# Result:
# These subsets provide insights into different categories of data based on the HCP identification and taxonomy information. By analyzing these subsets separately, you can gain insights into the prevalence and characteristics of HCPs without taxonomy, the distribution of HCPs with taxonomy, and the overall data without HCP information.

# %%
# EDA for HCP identified but taxonomy not populated
print(hcp_no_taxonomy.describe())
sns.countplot(x="DEVICETYPE", data=hcp_no_taxonomy)
plt.xlabel("DEVICETYPE")
plt.ylabel("Count")
plt.title("Device Type Distribution for HCP (No Taxonomy)")
plt.show()
# Out:
#                   ID  PLATFORM_ID   USERZIPCODE  IS_HCP
# count    1867.000000  1867.000000   1811.000000  1867.0
# mean    57115.462239    10.649170  45233.150193     1.0
# std     32824.909660     4.276936  24895.916009     0.0
# min      1150.000000     2.000000    602.000000     1.0
# 25%     28521.000000     7.000000  21211.500000     1.0
# 50%     56931.000000    12.000000  43220.000000     1.0
# 75%     85666.000000    14.000000  54915.000000     1.0
# max    114742.000000    15.000000  98402.000000     1.0

# %% [markdown]
# Result:
# These insights can be helpful in identifying any patterns or trends specific to HCPs with missing taxonomy and gaining a better understanding of this subgroup within the larger dataset. Further analysis and exploration can be performed based on these initial insights to uncover more information and potentially address any issues related to missing taxonomy information for HCPs.

# %%
# EDA for both HCP and taxonomy identified
print(hcp_with_taxonomy.describe())
sns.countplot(x="CHANNELTYPE", data=hcp_with_taxonomy)
plt.xlabel("CHANNELTYPE")
plt.ylabel("Count")
plt.title("Channel Type Distribution for HCP (With Taxonomy)")
plt.show()
# Out:
#                   ID   PLATFORM_ID   USERZIPCODE   IS_HCP
# count   32313.000000  32313.000000  3.231300e+04  32313.0
# mean    57887.115217      3.317395  6.182524e+07      1.0
# std     32975.977354      2.415627  1.892908e+08      0.0
# min      1004.000000      1.000000  1.001000e+03      1.0
# 25%     29344.000000      2.000000  2.014900e+04      1.0
# 50%     57745.000000      2.000000  4.810800e+04      1.0
# 75%     86487.000000      3.000000  9.062000e+04      1.0
# max    114937.000000     15.000000  9.970149e+08      1.0

# %% [markdown]
# Result:
# These insights can be helpful in understanding the characteristics and behaviors of HCPs with populated taxonomy information. It can provide insights into the platforms and channels preferred by HCPs, potentially guiding marketing or communication strategies targeted at specific taxonomies or specializations

# %%
# EDA for no information about HCP
print(no_hcp_info.describe())
sns.scatterplot(x="USERZIPCODE", y="USERCITY", data=no_hcp_info)
plt.xlabel("USERZIPCODE")
plt.ylabel("USERCITY")
plt.title("User City vs. ZIP Code for No HCP Info")
plt.show()
# Out:
#                   ID   PLATFORM_ID    USERZIPCODE   IS_HCP
# count   79756.000000  79756.000000   75220.000000  79756.0
# mean    58021.944932      3.513692   45660.582983      0.0
# std     32858.167800      2.331055   30489.104719      0.0
# min      1001.000000      1.000000    1001.000000      0.0
# 25%     29555.750000      2.000000   19107.000000      0.0
# 50%     58087.500000      2.000000   38133.000000      0.0
# 75%     86466.250000      6.000000   76137.000000      0.0
# max    114932.000000     16.000000  127576.000000      0.0
# C:\Users\M.Nallaperumal\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 24 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\M.Nallaperumal\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 24 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# Result:
# These insights can be valuable for understanding the characteristics of the dataset where no HCP information is available. It provides a basis for further analysis and exploration to uncover any trends, patterns, or potential strategies to handle missing HCP information.
